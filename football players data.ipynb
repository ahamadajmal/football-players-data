# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# import numpy as np
# import pandas as pd
# import matplotlib as plt

# %%
df=pd.read_csv("C:/Users/Peer/Desktop/kaggle/football.csv")
df
# Out:
#        Unnamed: 0      ID                Name  Age  \
# 0               0  158023            L. Messi   31
# 1               1   20801   Cristiano Ronaldo   33
# 2               2  190871           Neymar Jr   26
# 3               3  193080              De Gea   27
# 4               4  192985        K. De Bruyne   27
# ...           ...     ...                 ...  ...
# 18202       18202  238813        J. Lundstram   19
# 18203       18203  243165  N. Christoffersson   19
# 18204       18204  241638           B. Worman   16
# 18205       18205  246268      D. Walker-Rice   17
# 18206       18206  246269           G. Nugent   16
#
#                                                 Photo Nationality  \
# 0      https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1       https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2      https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3      https://cdn.sofifa.org/players/4/19/193080.png       Spain
# ...

# %%
sns.boxplot(y=df['Overall'])
# Out:
# <AxesSubplot:ylabel='Overall'>

# %%
sns.distplot(df['StandingTackle'])
# Out:
# C:\Users\Peer\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='StandingTackle', ylabel='Density'>

# %%
plt.scatter(df['StandingTackle'],df['SlidingTackle'])

# %%
plt.hist(df['SlidingTackle'])
# Out:
# (array([ 547., 3126., 1937., 1421., 1065., 1896., 4021., 3200.,  866.,
#           80.]),
#  array([ 3. , 11.8, 20.6, 29.4, 38.2, 47. , 55.8, 64.6, 73.4, 82.2, 91. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.plot(df['SlidingTackle'])

# %%
plt.bar(df['SlidingTackle'],df['StandingTackle'])

plt.show()

# %%
plt.subplot(121)
plt.title("sliding tackle")
plt.hist(df['SlidingTackle'])

plt.subplot(122)
plt.title("StandingTackle")
plt.hist(df["StandingTackle"])

plt.show()

# %%
df['StandingTackle'].describe
# Out:
# <bound method NDFrame.describe of 0        28.0
# 1        31.0
# 2        24.0
# 3        21.0
# 4        58.0
#          ...
# 18202    48.0
# 18203    15.0
# 18204    13.0
# 18205    25.0
# 18206    43.0
# Name: StandingTackle, Length: 18207, dtype: float64>

# %%
sns.distplot(df['StandingTackle'],hist=False,color='r',rug=200)
# Out:
# C:\Users\Peer\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Peer\anaconda3\lib\site-packages\seaborn\distributions.py:2055: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='StandingTackle', ylabel='Density'>

# %%
plt.subplot(221)
plt.title("StandingTackle")
sns.distplot(df['StandingTackle'],hist=False,color='b')

plt.subplot(222)
plt.title("SlidingTackle")
sns.distplot(df['SlidingTackle'],hist=False,color='k')

plt.subplot(223)
plt.title("GKDiving")
sns.distplot(df["GKDiving"],hist=False,color='r')

plt.subplot(224)
plt.title("GKHandling")
sns.distplot(df["GKHandling"],hist=False,color='g')
# Out:
# C:\Users\Peer\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Peer\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
sns.jointplot('StandingTackle','SlidingTackle',df,color='r')
# Out:
# C:\Users\Peer\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y, data. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.jointplot('Overall','Potential',df)
plt.show()
# Out:
# C:\Users\Peer\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y, data. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.countplot(df['Age'])
sns.
# Out:
# C:\Users\Peer\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Age', ylabel='count'>

# %%
plt.boxplot(df['Age'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1d5107b3250>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1d5107b3910>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1d5107c1eb0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1d5107b3fd0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1d5107d7220>],
#  'means': []}
